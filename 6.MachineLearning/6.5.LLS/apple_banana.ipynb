# %% [markdown]
# <img src="https://www.fatalerrors.org/images/blog/c6b544ae87e97d71cb450e434a8818a6.jpg" width="400px">
#
# - apple width ≈ 6cm
# - apple length ≈ 6cm
# - banana width ≈ 4cm
# - banana length ≈ 8cm
#
# apple : 0
#
# banana : 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
def genetare_dataset(n):
    apple_width = np.random.normal(6, 1, n)
    apple_length = np.random.normal(6, 1, n)
    banana_width = np.random.normal(4, 1, n)
    banana_length = np.random.normal(8, 1, n)

    width = np.concatenate((apple_width, banana_width))
    length = np.concatenate((apple_length, banana_length))
    X = np.array([width, length]).T

    Y_apples = np.ones(n, dtype='int') * -1
    Y_bananas = np.ones(n, dtype='int')
    Y = np.concatenate((Y_apples, Y_bananas))

    return X, Y

# %%
X_train, Y_train = genetare_dataset(100)

# %%
X_train
# Out:
# array([[ 6.67669411,  4.77549547],
#        [ 6.48617762,  5.63567455],
#        [ 5.61179552,  6.6362525 ],
#        [ 4.67757039,  7.5514248 ],
#        [ 5.61308942,  6.51374155],
#        [ 5.63676374,  5.29475277],
#        [ 7.79996435,  5.85425409],
#        [ 5.59986513,  7.72829142],
#        [ 5.89979637,  5.80646746],
#        [ 8.03321154,  6.05941621],
#        [ 6.15336035,  5.62153164],
#        [ 7.41022523,  5.92092963],
#        [ 5.64349774,  5.57241967],
#        [ 5.83727121,  5.89188769],
#        [ 5.4268922 ,  3.94342842],
#        [ 5.19617357,  8.11788779],
#        [ 6.27752498,  6.78741682],
#        [ 5.67771929,  5.7773779 ],
#        [ 6.58845236,  7.53258399],
#        [ 4.51543989,  5.31042717],
#        [ 4.06128678,  4.88398768],
#        [ 6.53847857,  5.85513896],
#        [ 4.51022126,  5.92313538],
#        [ 4.65376057,  6.77071817],
#        [ 4.89968026,  4.30167203],
#        [ 6.99622274,  6.94418333],
#        [ 6.69102515,  6.67219164],
#        [ 2.94560856,  7.21549963],
#        [ 7.59634501,  6.43097456],
#        [ 7.05048635,  7.45435829],
#        [ 3.63976973,  5.68195167],
#        [ 5.07579396,  5.0634797 ],
#        [ 5.62860454,  8.07381708],
#        [ 5.19162097,  5.87699442],
#        [ 6.89571557,  7.72797649],
#        [ 6.78769665,  5.04684876],
#        [ 5.01162054,  5.32907384],
#        [ 4.82252711,  3.71030463],
#        [ 5.75954201,  6.41170855],
#        [ 5.98597717,  5.79766803],
#        [ 6.76424891,  5.39640432],
#        [ 5.7923555 ,  6.01744368],
#        [ 7.65653711,  3.69993993],
#        [ 6.6154386 ,  6.3895215 ],
#        [ 6.19559492,  5.56985312],
#        [ 5.16391474,  8.95933731],
#        [ 5.98140686,  6.15794724],
#        [ 7.10345145,  5.4661378 ],
#        [ 6.21545336,  5.93617247],
#        [ 6.38037924,  7.70120453],
#        [ 7.13702682,  6.01342197],
#        [ 6.14652472,  5.1921712 ],
#        [ 6.02055012,  6.42517463],
#        [ 6.41059632,  6.64277303],
#        [ 7.28388171,  4.76741651],
#        [ 7.42895684,  5.70128505],
#        [ 5.64887484,  6.33667935],
#        [ 5.47986873,  6.32509997],
#        [ 6.55063068,  6.71223201],
#        [ 4.9301272 ,  6.24312685],
#        [ 4.7049743 ,  5.72298006],
#        [ 5.93609132,  6.52094725],
#        [ 6.75603321,  6.78823707],
#        [ 5.66886227,  5.75021291],
#        [ 2.97097289,  7.78256688],
#        [ 4.88806038,  7.09846252],
#        [ 3.48379845,  7.6875661 ],
#        [ 3.14604042,  9.55484068],
#        [ 3.7274863 ,  8.12331668],
#        [ 5.334994  ,  5.90651527],
#        [ 4.62549957,  9.12092926],
#        [ 5.08136058,  8.66908733],
#        [ 4.45965753,  7.19639358],
#        [ 3.9523043 ,  9.53972532],
#        [ 6.07681718,  6.71967848],
#        [ 3.90686969,  9.01249426],
#        [ 1.75494285,  7.23769646],
#        [ 3.59626164,  7.94332767],
#        [ 3.24713601,  6.68008385],
#        [ 5.16272881,  6.94281441],
#        [ 4.13628504,  7.64612281],
#        [ 3.73307646,  9.3088436 ],
#        [ 5.30077497,  8.94765586],
#        [ 3.35193857,  9.47908434],
#        [ 4.16438961,  6.89862661],
#        [ 3.38549766,  8.01298568],
#        [ 4.25681056,  9.45118951],
#        [ 4.21945625,  8.52829967],
#        [ 1.80420127,  8.41756909],
#        [ 5.36917771,  8.18464699],
#        [ 5.27716872,  6.9497016 ],
#        [ 3.95047379,  7.0270294 ],
#        [ 3.60709389,  7.70543494],
#        [ 4.60214228,  8.35410274],
#        [ 5.21500607, 10.19832875],
#        [ 3.07608714,  9.05673985],
#        [ 4.90948158,  9.08022562],
#        [ 4.59314938,  9.07920121],
#        [ 2.62182586,  6.95702585],
#        [ 4.55040967, 10.05397634],
#        [ 2.38226361,  7.63872328],
#        [ 4.20750006,  7.00274416],
#        [ 4.45421622,  7.03991783],
#        [ 2.83337292,  8.08547907],
#        [ 2.01976732,  9.0371527 ],
#        [ 6.06091055,  7.93108942],
#        [ 5.00097874,  7.52973585],
#        [ 3.3341725 ,  8.04194973],
#        [ 4.93462792,  8.84906592],
#        [ 2.98889828,  8.44469542],
#        [ 4.52422361,  7.72109389],
#        [ 1.56132999,  6.31165015],
#        [ 3.69885661,  8.80934847],
#        [ 4.61519614,  7.16246319],
#        [ 4.49601849,  7.96708065]])

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train, cmap=ListedColormap(['red', 'orange']))
plt.title('Apple and Banana')
plt.xlabel('width')
plt.ylabel('length')
plt.show()

# %%
from sklearn.linear_model import SGDClassifier

# %%
clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=5)
clf.fit(X_train, Y_train)
# Out:
# C:\Users\Sajjad\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDClassifier(max_iter=5)

# %%
new_fruit_1 = np.array([3, 8.4])
new_fruit_2 = np.array([6, 6])
new_fruit_3 = np.array([4, 7])

new_fruits = [new_fruit_1, new_fruit_2, new_fruit_3]

# %%
outputs = clf.predict(new_fruits)
outputs
# Out:
# array([ 1, -1,  1])

# %%
for output in outputs:
    if output == -1:
        print('🍎')
    else:
        print('🍌')
# Out:
# 🍌
# 🍎
# 🍌

# %%
w = clf.coef_
w
# Out:
# array([[-242.79725547,  203.66373381]])

# %%
b = clf.intercept_
b
# Out:
# array([-22.19167249])

# %%
# visualize the line

line = -(range(0, 8) * w[0, 0] + b) / w[0, 1]

# %%
plt.plot(x, line, '-g', lw=2)
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train, cmap=ListedColormap(['red', 'orange']))
plt.title('Apple and Banana')
plt.xlabel('width')
plt.ylabel('length')
plt.show()

# %%
X_test, Y_test = genetare_dataset(90)

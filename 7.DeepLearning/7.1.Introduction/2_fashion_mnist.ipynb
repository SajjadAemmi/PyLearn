# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train),(x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap="gray")
    plt.xlabel(y_train[i])

plt.show()

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.5252 - accuracy: 0.8148
# Epoch 2/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3995 - accuracy: 0.8558
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3628 - accuracy: 0.8669
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3456 - accuracy: 0.8738
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3288 - accuracy: 0.8778

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3642 - accuracy: 0.8687
# [0.36420097947120667, 0.8687000274658203]
